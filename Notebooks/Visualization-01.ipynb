# %% [markdown]
# # EDA( Exploratory Data Analysis)
# * All about the datasets
# * colums /features/ index,independent variable
# * target variable /dependent variable

# %% [markdown]
# # All figure in 2D

# %%
# lib's
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Dataframes 
iris = pd.read_csv('Datasets/Iris.csv')

iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
print("shape :",iris.shape)
# Out:
# shape : (150, 6)

# %%
# features of iris datasets
features = iris.columns
features = features[1:-1].tolist()
features
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# check the value of the target variable
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# visualization in 2D
# this is 2D plot what about 3D ,4D,5D plots

plt.scatter(iris['SepalLengthCm'],iris['SepalWidthCm'],marker='.')
plt.xlabel('SepalLength Cm')
plt.ylabel('SepalWidth Cm')
plt.show()

# %%
# 3D plot using Seaborn lib 
import seaborn as sns
# observation 
# * we can differentciate by sepal lenght and width just look like the linear separable
g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(plt.scatter,'SepalLengthCm','SepalWidthCm',).add_legend()
plt.show()

# %%
g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(plt.scatter,'SepalLengthCm','PetalLengthCm',).add_legend()
plt.show()

# %%
g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(plt.scatter,'SepalLengthCm','PetalWidthCm',).add_legend()
plt.show()

# %% [markdown]
# # In 3D plots
#
# In Pairplot did very great job but what happen when we have large number of the features
# then as humen that make us tired and become un-undertandable form of the data
# but in the that problem we have different tools to solve this problem like Dimesionality reduction techniques

# %%
sns.pairplot(iris.drop(columns=['Id']),hue='Species', height=4)

# %% [markdown]
# # Univariate Analysis
#
# univariate Analysis work on the PDF and give us idea how to distribution of the function in
# the form of histogram
# **observation**
# * petal lenght can do more work in order to selecting the model and classifying the problems

# %%
g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(sns.distplot ,'SepalLengthCm').add_legend()
plt.show();
# you can see below petal lenght is very mxture with other features


g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(sns.distplot ,'SepalWidthCm').add_legend()
plt.show()
# alos mixture distribution


g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(sns.distplot ,'PetalLengthCm').add_legend()
plt.show()

# but her petal lenght is clear saturated with 
# other features but versicolor and virgnica still mixed with each other


g = sns.FacetGrid(iris,hue='Species',height=4)
g.map(sns.distplot ,'PetalWidthCm').add_legend()
plt.show();

# %% [markdown]
# # Mean ,Variance , Standard Variance
# * **Mean**
#     * Mean is failed to detect the outlier ,one wrong input can make the wrog the output
# * **Variance**
#     * Variance actually tell us the spread of the data from the mean
#     * if we know the mean and variance then we can imagine of the data where they are laying
# * **Standard Variance**
#     * std-var is nothing this just the square of the variance to remove the effect of the negative sign of the distance from each point from the mean of the whole data
# * **Median**
#     * By median you crack the mean problem what is mean problem we can go wrong if the outlier is under obervation>
#     * Median hack the problem by sort it first and pick the middle value then we can observe the how much data is my left side and how much data is on my right side.
#     * But there is also problem for example List = [1.1,1.2,1.3,1.5,10,20,30,40,50] then the mean of this problem is we got medain of this problem is 1.5 . Do you think this is right interpretation ?
#     * No this is wrong interpretation . The point is When we have more then 50 percent data is outlier then Median would fail.
# * **Percentile**
#     * Percentile is nothing it is just tell us the percentage of the data. 25 percentile is the 25 percentage of the data is liying in thpose Range.
#        * **Example**
#            * order dlivery list = [1,1.5,2,3,4,5,6]
#            * if we check th the 90 percentile is mean of the 90 percentage of the people are getting in five days

# %%
petalLenght_mean = np.mean(iris.PetalLengthCm)
print(petalLenght_mean)
petal_width_mean= np.mean(iris.PetalWidthCm)
print(petal_width_mean)
# Out:
# 3.7586666666666693
# 1.1986666666666672

# %% [markdown]
# # Boxplots
# **What is the boxplot and intutions?**
#    * Boxplot is nothing it is just representation of percentile with 25th and 50th and 75th and 100th of data.
#    * upper and lower line also called wisker . Wisker represent the max and min value and but generally have differnent methods of wisker.
#     * for example whisker is defined as 2 * IQR
#         * **What is IQR**?
#             * IQR is datal between 75 percentile and 25 percentile.

# %%
sns.boxplot(x = 'Species' ,y = 'PetalLengthCm' ,data=iris)

# %%
features
# Out:
# ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']

# %%
sns.boxplot(x = 'Species' ,y = 'SepalWidthCm' ,data=iris)

# %%
sns.boxplot(x = 'Species' ,y = 'PetalLengthCm' ,data=iris)

# %%
sns.boxplot(x = 'Species' ,y = 'PetalWidthCm' ,data=iris)

# %% [markdown]
# # ViolinPlot
#  * Violinplot is nothing just Enhance the information in the histogram.
#  * Actually there is displot in side the violinplot .There is 25th ,50th,75th percentile but there is representation of the Normal distribution .
#  * In the both side you can actually look there look like bell curve mean normal distribution of the data and Guassain distribution of the data.

# %%
sns.violinplot(x = 'Species' ,y = 'SepalWidthCm' ,data=iris)

# %% [markdown]
# **Observation**
#    * Curve representing the distribution of the datasets.

# %%
sns.violinplot(x = 'Species' ,y = 'PetalLengthCm' ,data=iris)

# %%
sns.violinplot(x = 'Species' ,y = 'PetalWidthCm' ,data=iris)
